# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# Standard plotly imports
#import plotly.plotly as py
import plotly.graph_objs as go
import plotly.tools as tls
from plotly.offline import iplot, init_notebook_mode
#import cufflinks
#import cufflinks as cf
import plotly.figure_factory as ff

# Using plotly + cufflinks in offline mode
init_notebook_mode(connected=True)
#cufflinks.go_offline(connected=True)

# Preprocessing, modelling and evaluating
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold
from xgboost import XGBClassifier
import xgboost as xgb

## Hyperopt modules
from hyperopt import fmin, hp, tpe, Trials, space_eval, STATUS_OK, STATUS_RUNNING
from functools import partial

import os
import gc
print(os.listdir("../input"))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ['new-train', 'data-science-bowl-2019']

# %% [markdown]
# ## Modelling
# To start simple, I will start using as base the kernels below: <br>
# https://www.kaggle.com/artkulak/ieee-fraud-simple-baseline-0-9383-lb - (@artkulak - Art) <br>
# https://www.kaggle.com/artgor/eda-and-models - (@artgor - Andrew Lukyanenko)

# %%
train_data = pd.read_csv('../input/new-train/new_train_v24_concat.csv')

# %%
def preprocess(train_data):
        ## Null values
    for i in ['time_percentage', 'Clip_time_per', 'Activity_time_per', 'Game_time_per', 'code_4xx_time']:
    
        train_data[i].fillna(0, inplace=True)

    for i in ['Scrub-A-Dub_process_Acc', 'All Star Sorting_process_Acc',
           'Air Show_process_Acc', 'Crystals Rule_process_Acc',
           'Dino Drink_process_Acc', 'Bubble Bath_process_Acc',
           'Dino Dive_process_Acc', 'Chow Time_process_Acc',
           'Pan Balance_process_Acc', 'Happy Camel_process_Acc',
           'Leaf Leader_process_Acc']:
        
        train_data[i].fillna(0, inplace=True)
        
            ### Assessment dictionary
    assess_list = {'Mushroom Sorter (Assessment)': 0, 
                   'Bird Measurer (Assessment)': 1, 
                   'Cauldron Filler (Assessment)': 2, 
                   'Chest Sorter (Assessment)': 3,
                   'Cart Balancer (Assessment)': 4}

    del_clip = ['Welcome to Lost Lagoon!', 'Magma Peak - Level 1', 'Slop Problem',
           'Tree Top City - Level 1', 'Ordering Spheres', 'Costume Box',
           '12 Monkeys', 'Tree Top City - Level 2',"Pirate's Tale",
           'Treasure Map', 'Tree Top City - Level 3', 'Rulers',
           'Magma Peak - Level 2', 'Crystal Caves - Level 1', 'Balancing Act',
           'Crystal Caves - Level 2', 'Crystal Caves - Level 3',
           'Lifting Heavy Things', 'Honey Cake', 'Heavy, Heavier, Heaviest']

    del_duration = ['Scrub-A-Dub_duration_y', 'Dino Drink_duration_y',
       'All Star Sorting_duration_y', 'Air Show_duration_y',
       'Crystals Rule_duration_y', 'Bubble Bath_duration_y',
       'Dino Dive_duration_y', 'Chow Time_duration_y',
       'Pan Balance_duration_y', 'Happy Camel_duration_y',
       'Leaf Leader_duration_y', 'Mushroom Sorter (Assessment)_duration',
       'Bird Measurer (Assessment)_duration',
       'Cauldron Filler (Assessment)_duration',
       'Cart Balancer (Assessment)_duration',
       'Chest Sorter (Assessment)_duration']
        
    ### 1. Assessment encoding
    train_data['title'] = train_data['title'].map(assess_list)
    
    ### ** Group ###
    group_train = train_data['title'].values
    
    ### 2. Make title column to dummy columns
    train_data = pd.concat([train_data, pd.get_dummies(train_data['title'], prefix='Assess_')], axis=1)
    
    
    ### 3. Target column
    target = train_data['accuracy_group'].copy()

    ### 4. Drop columns
    train_data.drop(columns=(['installation_id', 'game_session', 'title',
                              'num_correct', 'num_incorrect', 'acc', 'accuracy_group']), inplace=True)
    
    
    ### 5. Drop previous Game features
    train_data.drop(columns=del_clip, inplace=True, errors='ignore')
    train_data.drop(columns=del_duration, inplace=True, errors='ignore')   
    
    return train_data, target, group_train

# %%
train_data, target, group_train = preprocess(train_data)

# %%
X_train = train_data
y_train = target

X = train_data.values
y = target.values

# %% [markdown]
# # Defining the HyperOpt function with parameters space and model

# %%
import pickle

# %%
with open('../input/new-train/val_dict_add2.pkl', 'rb') as f:
    val_dict = pickle.load(f)

# %%
from sklearn.model_selection import KFold,TimeSeriesSplit
from sklearn.metrics import roc_auc_score, mean_squared_error
from xgboost import plot_importance
from sklearn.metrics import make_scorer

import time
def objective(params):
    time1 = time.time()
    params = {
        'max_depth': int(params['max_depth']),
        'gamma': "{:.3f}".format(params['gamma']),
        'subsample': "{:.2f}".format(params['subsample']),
        'reg_alpha': "{:.3f}".format(params['reg_alpha']),
        'reg_lambda': "{:.3f}".format(params['reg_lambda']),
        'learning_rate': "{:.3f}".format(params['learning_rate']),
        'num_leaves': '{:.3f}'.format(params['num_leaves']),
        'colsample_bytree': '{:.3f}'.format(params['colsample_bytree']),
        'min_child_samples': '{:.3f}'.format(params['min_child_samples']),
        'feature_fraction': '{:.3f}'.format(params['feature_fraction']),
        'bagging_fraction': '{:.3f}'.format(params['bagging_fraction'])
    }

    print("\n############## New Run ################")
    print(f"params = {params}")
    FOLDS = 7
    count=1

    #y_preds = np.zeros(sample_submission.shape[0])
    y_oof = np.zeros(X_train.shape[0])
    score_mean = 0
    
    for n_fold in range(5):
        print("="*50)
        print('Training Start, fold : {}'.format(n_fold+1))
        print("="*50)
        val_idx = val_dict[n_fold]
        tr_idx = train_data.index[train_data.index.isin(val_idx) == False]
        
        clf = xgb.XGBRegressor(
            n_estimators=200, random_state=4, verbose=True, 
            tree_method='gpu_hist', 
            **params
        )
        X_tr, y_tr = X[tr_idx], y[tr_idx]
        X_vl, y_vl = X[val_idx], y[val_idx]
        
        #X_tr, X_vl = X_train.iloc[tr_idx, :], X_train.iloc[tr_idx, :]
        #y_tr, y_vl = y_train.iloc[val_idx], y_train.iloc[val_idx]
        
        clf.fit(X_tr, y_tr)
        #y_pred_train = clf.predict_proba(X_vl)[:,1]
        #print(y_pred_train)
        #score = make_scorer(mean_squared_error, needs_proba=True)(clf, X_vl, y_vl)
        score = mean_squared_error(clf.predict(X_vl), y_vl)
        # plt.show()
        score_mean += score
        print(f'{count} CV - score: {round(score, 4)}')
        count += 1
    time2 = time.time() - time1
    print(f"Total Time Run: {round(time2 / 60,2)}")
    gc.collect()
    print(f'Mean ROC_AUC: {score_mean / FOLDS}')
    del X_tr, X_vl, y_tr, y_vl, clf, score
    return -(score_mean / FOLDS)


space = {
    # The maximum depth of a tree, same as GBM.
    # Used to control over-fitting as higher depth will allow model 
    # to learn relations very specific to a particular sample.
    # Should be tuned using CV.
    # Typical values: 3-10
    'max_depth': hp.quniform('max_depth', 7, 23, 1),
    
    # reg_alpha: L1 regularization term. L1 regularization encourages sparsity 
    # (meaning pulling weights to 0). It can be more useful when the objective
    # is logistic regression since you might need help with feature selection.
    'reg_alpha':  hp.uniform('reg_alpha', 0.01, 0.4),
    
    # reg_lambda: L2 regularization term. L2 encourages smaller weights, this
    # approach can be more useful in tree-models where zeroing 
    # features might not make much sense.
    'reg_lambda': hp.uniform('reg_lambda', 0.01, .4),
    
    # eta: Analogous to learning rate in GBM
    # Makes the model more robust by shrinking the weights on each step
    # Typical final values to be used: 0.01-0.2
    'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
    
    # colsample_bytree: Similar to max_features in GBM. Denotes the 
    # fraction of columns to be randomly samples for each tree.
    # Typical values: 0.5-1
    'colsample_bytree': hp.uniform('colsample_bytree', 0.3, .9),
    
    # A node is split only when the resulting split gives a positive
    # reduction in the loss function. Gamma specifies the 
    # minimum loss reduction required to make a split.
    # Makes the algorithm conservative. The values can vary depending on the loss function and should be tuned.
    'gamma': hp.uniform('gamma', 0.01, .7),
    
    # more increases accuracy, but may lead to overfitting.
    # num_leaves: the number of leaf nodes to use. Having a large number 
    # of leaves will improve accuracy, but will also lead to overfitting.
    'num_leaves': hp.choice('num_leaves', list(range(20, 250, 10))),
    
    # specifies the minimum samples per leaf node.
    # the minimum number of samples (data) to group into a leaf. 
    # The parameter can greatly assist with overfitting: larger sample
    # sizes per leaf will reduce overfitting (but may lead to under-fitting).
    'min_child_samples': hp.choice('min_child_samples', list(range(100, 250, 10))),
    
    # subsample: represents a fraction of the rows (observations) to be 
    # considered when building each subtree. Tianqi Chen and Carlos Guestrin
    # in their paper A Scalable Tree Boosting System recommend 
    'subsample': hp.choice('subsample', [0.2, 0.4, 0.5, 0.6, 0.7, .8, .9]),
    
    # randomly select a fraction of the features.
    # feature_fraction: controls the subsampling of features used
    # for training (as opposed to subsampling the actual training data in 
    # the case of bagging). Smaller fractions reduce overfitting.
    'feature_fraction': hp.uniform('feature_fraction', 0.4, .8),
    
    # randomly bag or subsample training data.
    'bagging_fraction': hp.uniform('bagging_fraction', 0.4, .9)
    
    # bagging_fraction and bagging_freq: enables bagging (subsampling) 
    # of the training data. Both values need to be set for bagging to be used.
    # The frequency controls how often (iteration) bagging is used. Smaller
    # fractions and frequencies reduce overfitting.
}

# %% [markdown]
# # Running the optimizer

# %%
# Set algoritm parameters
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=27)

# Print best parameters
best_params = space_eval(space, best)
# Out:
#
# ############## New Run ################
# params = {'max_depth': 13, 'gamma': '0.360', 'subsample': '0.90', 'reg_alpha': '0.303', 'reg_lambda': '0.122', 'learning_rate': '0.119', 'num_leaves': '170.000', 'colsample_bytree': '0.341', 'min_child_samples': '120.000', 'feature_fraction': '0.561', 'bagging_fraction': '0.432'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [18:52:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.0441
# ==================================================
# Training Start, fold : 2
# ==================================================
# [18:52:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.0384
# ==================================================
# Training Start, fold : 3
# ==================================================
# [18:53:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.0015
# ==================================================
# Training Start, fold : 4
# ==================================================
# [18:53:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.0418
# ==================================================
# Training Start, fold : 5
# ==================================================
# [18:53:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.041
# Total Time Run: 0.83
# Mean ROC_AUC: 0.7381209679085384
#
# ############## New Run ################
# params = {'max_depth': 14, 'gamma': '0.609', 'subsample': '0.70', 'reg_alpha': '0.019', 'reg_lambda': '0.100', 'learning_rate': '0.092', 'num_leaves': '240.000', 'colsample_bytree': '0.800', 'min_child_samples': '240.000', 'feature_fraction': '0.703', 'bagging_fraction': '0.710'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [18:53:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.0774
# ==================================================
# Training Start, fold : 2
# ==================================================
# [18:53:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.0517
# ==================================================
# Training Start, fold : 3
# ==================================================
# [18:54:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.0232
# ==================================================
# Training Start, fold : 4
# ==================================================
# [18:54:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.0756
# ==================================================
# Training Start, fold : 5
# ==================================================
# [18:54:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.0586
# Total Time Run: 1.29
# Mean ROC_AUC: 0.7552189022583037
#
# ############## New Run ################
# params = {'max_depth': 12, 'gamma': '0.507', 'subsample': '0.50', 'reg_alpha': '0.012', 'reg_lambda': '0.059', 'learning_rate': '0.108', 'num_leaves': '200.000', 'colsample_bytree': '0.671', 'min_child_samples': '150.000', 'feature_fraction': '0.757', 'bagging_fraction': '0.766'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [18:54:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.1089
# ==================================================
# Training Start, fold : 2
# ==================================================
# [18:55:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.0855
# ==================================================
# Training Start, fold : 3
# ==================================================
# [18:55:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.0476
# ==================================================
# Training Start, fold : 4
# ==================================================
# [18:55:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.101
# ==================================================
# Training Start, fold : 5
# ==================================================
# [18:55:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.0733
# Total Time Run: 0.72
# Mean ROC_AUC: 0.7737737927704578
#
# ############## New Run ################
# params = {'max_depth': 10, 'gamma': '0.544', 'subsample': '0.90', 'reg_alpha': '0.061', 'reg_lambda': '0.361', 'learning_rate': '0.160', 'num_leaves': '30.000', 'colsample_bytree': '0.419', 'min_child_samples': '140.000', 'feature_fraction': '0.581', 'bagging_fraction': '0.419'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [18:55:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.0624
# ==================================================
# Training Start, fold : 2
# ==================================================
# [18:55:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.0588
# ==================================================
# Training Start, fold : 3
# ==================================================
# [18:55:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.0113
# ==================================================
# Training Start, fold : 4
# ==================================================
# [18:55:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.0739
# ==================================================
# Training Start, fold : 5
# ==================================================
# [18:55:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.0415
# Total Time Run: 0.4
# Mean ROC_AUC: 0.7496983178881381
#
# ############## New Run ################
# params = {'max_depth': 17, 'gamma': '0.605', 'subsample': '0.20', 'reg_alpha': '0.289', 'reg_lambda': '0.192', 'learning_rate': '0.054', 'num_leaves': '240.000', 'colsample_bytree': '0.399', 'min_child_samples': '140.000', 'feature_fraction': '0.609', 'bagging_fraction': '0.879'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [18:55:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.0719
# ==================================================
# Training Start, fold : 2
# ==================================================
# [18:56:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.0775
# ==================================================
# Training Start, fold : 3
# ==================================================
# [18:56:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.0245
# ==================================================
# Training Start, fold : 4
# ==================================================
# [18:56:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.0785
# ==================================================
# Training Start, fold : 5
# ==================================================
# [18:56:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.0508
# Total Time Run: 0.95
# Mean ROC_AUC: 0.7575859976231978
#
# ############## New Run ################
# params = {'max_depth': 22, 'gamma': '0.221', 'subsample': '0.50', 'reg_alpha': '0.159', 'reg_lambda': '0.160', 'learning_rate': '0.172', 'num_leaves': '140.000', 'colsample_bytree': '0.752', 'min_child_samples': '160.000', 'feature_fraction': '0.786', 'bagging_fraction': '0.774'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [18:56:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.1513
# ==================================================
# Training Start, fold : 2
# ==================================================
# [18:57:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.1448
# ==================================================
# Training Start, fold : 3
# ==================================================
# [18:58:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.1265
# ==================================================
# Training Start, fold : 4
# ==================================================
# [18:58:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.1835
# ==================================================
# Training Start, fold : 5
# ==================================================
# [18:59:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.1631
# Total Time Run: 2.85
# Mean ROC_AUC: 0.8241694064740747
#
# ############## New Run ################
# params = {'max_depth': 14, 'gamma': '0.676', 'subsample': '0.20', 'reg_alpha': '0.283', 'reg_lambda': '0.301', 'learning_rate': '0.163', 'num_leaves': '80.000', 'colsample_bytree': '0.439', 'min_child_samples': '120.000', 'feature_fraction': '0.728', 'bagging_fraction': '0.482'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [18:59:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.3853
# ==================================================
# Training Start, fold : 2
# ==================================================
# [18:59:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.3802
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:00:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.3003
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:00:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.3516
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:00:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.376
# Total Time Run: 0.62
# Mean ROC_AUC: 0.9704892356285411
#
# ############## New Run ################
# params = {'max_depth': 18, 'gamma': '0.295', 'subsample': '0.70', 'reg_alpha': '0.039', 'reg_lambda': '0.022', 'learning_rate': '0.113', 'num_leaves': '50.000', 'colsample_bytree': '0.312', 'min_child_samples': '240.000', 'feature_fraction': '0.667', 'bagging_fraction': '0.877'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:00:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.1149
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:00:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.077
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:01:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.0494
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:01:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.0865
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:02:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.0639
# Total Time Run: 2.18
# Mean ROC_AUC: 0.7702297680481901
#
# ############## New Run ################
# params = {'max_depth': 18, 'gamma': '0.406', 'subsample': '0.60', 'reg_alpha': '0.376', 'reg_lambda': '0.383', 'learning_rate': '0.021', 'num_leaves': '50.000', 'colsample_bytree': '0.519', 'min_child_samples': '150.000', 'feature_fraction': '0.499', 'bagging_fraction': '0.715'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:02:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 0.9979
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:03:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 0.9861
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:03:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 0.948
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:03:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 0.997
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:04:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 0.9796
# Total Time Run: 2.27
# Mean ROC_AUC: 0.7012372918542192
#
# ############## New Run ################
# params = {'max_depth': 8, 'gamma': '0.015', 'subsample': '0.60', 'reg_alpha': '0.049', 'reg_lambda': '0.207', 'learning_rate': '0.086', 'num_leaves': '70.000', 'colsample_bytree': '0.309', 'min_child_samples': '110.000', 'feature_fraction': '0.708', 'bagging_fraction': '0.530'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:04:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.0192
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:04:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.0024
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:04:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 0.9494
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:04:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.0003
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:05:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.0054
# Total Time Run: 0.2
# Mean ROC_AUC: 0.7109611644277732
#
# ############## New Run ################
# params = {'max_depth': 10, 'gamma': '0.678', 'subsample': '0.50', 'reg_alpha': '0.323', 'reg_lambda': '0.057', 'learning_rate': '0.171', 'num_leaves': '140.000', 'colsample_bytree': '0.622', 'min_child_samples': '220.000', 'feature_fraction': '0.766', 'bagging_fraction': '0.872'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:05:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.1533
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:05:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.1465
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:05:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.1009
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:05:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.1292
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:05:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.1453
# Total Time Run: 0.36
# Mean ROC_AUC: 0.8107426254383547
#
# ############## New Run ################
# params = {'max_depth': 13, 'gamma': '0.534', 'subsample': '0.80', 'reg_alpha': '0.225', 'reg_lambda': '0.305', 'learning_rate': '0.049', 'num_leaves': '130.000', 'colsample_bytree': '0.377', 'min_child_samples': '200.000', 'feature_fraction': '0.580', 'bagging_fraction': '0.582'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:05:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.0118
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:05:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 0.9953
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:05:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 0.9517
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:06:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.0111
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:06:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 0.9912
# Total Time Run: 1.0
# Mean ROC_AUC: 0.7087240231155612
#
# ############## New Run ################
# params = {'max_depth': 11, 'gamma': '0.348', 'subsample': '0.70', 'reg_alpha': '0.079', 'reg_lambda': '0.298', 'learning_rate': '0.016', 'num_leaves': '140.000', 'colsample_bytree': '0.894', 'min_child_samples': '130.000', 'feature_fraction': '0.481', 'bagging_fraction': '0.849'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:06:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 0.9885
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:06:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 0.9774
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:06:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 0.9401
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:06:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 0.9825
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:07:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 0.9778
# Total Time Run: 0.9
# Mean ROC_AUC: 0.695171764295752
#
# ############## New Run ################
# params = {'max_depth': 22, 'gamma': '0.516', 'subsample': '0.50', 'reg_alpha': '0.065', 'reg_lambda': '0.370', 'learning_rate': '0.158', 'num_leaves': '170.000', 'colsample_bytree': '0.350', 'min_child_samples': '130.000', 'feature_fraction': '0.682', 'bagging_fraction': '0.428'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:07:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.161
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:07:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.1534
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:08:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.1308
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:09:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.1346
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:09:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.1441
# Total Time Run: 2.86
# Mean ROC_AUC: 0.8177040295939632
#
# ############## New Run ################
# params = {'max_depth': 11, 'gamma': '0.031', 'subsample': '0.70', 'reg_alpha': '0.124', 'reg_lambda': '0.154', 'learning_rate': '0.023', 'num_leaves': '120.000', 'colsample_bytree': '0.587', 'min_child_samples': '230.000', 'feature_fraction': '0.438', 'bagging_fraction': '0.744'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:10:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 0.9782
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:10:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 0.9715
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:10:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 0.9287
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:10:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 0.9775
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:10:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 0.969
# Total Time Run: 0.75
# Mean ROC_AUC: 0.6892620405254991
#
# ############## New Run ################
# params = {'max_depth': 10, 'gamma': '0.087', 'subsample': '0.50', 'reg_alpha': '0.320', 'reg_lambda': '0.196', 'learning_rate': '0.149', 'num_leaves': '170.000', 'colsample_bytree': '0.309', 'min_child_samples': '190.000', 'feature_fraction': '0.676', 'bagging_fraction': '0.626'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:10:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.0981
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:11:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.0963
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:11:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.0426
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:11:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.0917
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:11:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.1024
# Total Time Run: 0.35
# Mean ROC_AUC: 0.7758907255421168
#
# ############## New Run ################
# params = {'max_depth': 16, 'gamma': '0.133', 'subsample': '0.80', 'reg_alpha': '0.188', 'reg_lambda': '0.051', 'learning_rate': '0.184', 'num_leaves': '240.000', 'colsample_bytree': '0.579', 'min_child_samples': '240.000', 'feature_fraction': '0.479', 'bagging_fraction': '0.405'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:11:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.1202
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:11:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.1042
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:11:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.069
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:12:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.1279
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:12:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.0869
# Total Time Run: 1.42
# Mean ROC_AUC: 0.7868862119095599
#
# ############## New Run ################
# params = {'max_depth': 16, 'gamma': '0.563', 'subsample': '0.60', 'reg_alpha': '0.056', 'reg_lambda': '0.280', 'learning_rate': '0.022', 'num_leaves': '170.000', 'colsample_bytree': '0.611', 'min_child_samples': '170.000', 'feature_fraction': '0.422', 'bagging_fraction': '0.556'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:12:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.0002
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:13:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 0.9863
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:13:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 0.9514
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:13:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.0041
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:14:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 0.9899
# Total Time Run: 2.1
# Mean ROC_AUC: 0.704565975144595
#
# ############## New Run ################
# params = {'max_depth': 14, 'gamma': '0.259', 'subsample': '0.90', 'reg_alpha': '0.273', 'reg_lambda': '0.345', 'learning_rate': '0.189', 'num_leaves': '170.000', 'colsample_bytree': '0.663', 'min_child_samples': '140.000', 'feature_fraction': '0.414', 'bagging_fraction': '0.473'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:14:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.1073
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:15:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.0848
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:15:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.0486
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:15:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.1056
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:15:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.0707
# Total Time Run: 1.02
# Mean ROC_AUC: 0.7738552075698619
#
# ############## New Run ################
# params = {'max_depth': 15, 'gamma': '0.118', 'subsample': '0.20', 'reg_alpha': '0.010', 'reg_lambda': '0.231', 'learning_rate': '0.094', 'num_leaves': '130.000', 'colsample_bytree': '0.645', 'min_child_samples': '110.000', 'feature_fraction': '0.498', 'bagging_fraction': '0.683'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:15:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.2192
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:16:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.2314
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:16:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.1589
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:16:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.199
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:16:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.1952
# Total Time Run: 0.86
# Mean ROC_AUC: 0.8576668238253907
#
# ############## New Run ################
# params = {'max_depth': 19, 'gamma': '0.166', 'subsample': '0.20', 'reg_alpha': '0.239', 'reg_lambda': '0.245', 'learning_rate': '0.133', 'num_leaves': '80.000', 'colsample_bytree': '0.500', 'min_child_samples': '100.000', 'feature_fraction': '0.521', 'bagging_fraction': '0.664'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:16:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.3297
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:16:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.2713
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:17:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.2657
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:17:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.3212
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:17:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.3142
# Total Time Run: 1.12
# Mean ROC_AUC: 0.9288822802361788
#
# ############## New Run ################
# params = {'max_depth': 20, 'gamma': '0.189', 'subsample': '0.40', 'reg_alpha': '0.248', 'reg_lambda': '0.259', 'learning_rate': '0.134', 'num_leaves': '80.000', 'colsample_bytree': '0.478', 'min_child_samples': '100.000', 'feature_fraction': '0.620', 'bagging_fraction': '0.639'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:17:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.1403
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:18:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.1433
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:18:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.0962
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:18:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.1616
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:19:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.1545
# Total Time Run: 1.81
# Mean ROC_AUC: 0.8137077374884318
#
# ############## New Run ################
# params = {'max_depth': 20, 'gamma': '0.696', 'subsample': '0.20', 'reg_alpha': '0.372', 'reg_lambda': '0.327', 'learning_rate': '0.200', 'num_leaves': '220.000', 'colsample_bytree': '0.479', 'min_child_samples': '100.000', 'feature_fraction': '0.541', 'bagging_fraction': '0.492'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:19:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.5461
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:19:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.532
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:20:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.504
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:20:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.5482
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:20:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.5328
# Total Time Run: 1.21
# Mean ROC_AUC: 1.0947213150984239
#
# ############## New Run ################
# params = {'max_depth': 20, 'gamma': '0.691', 'subsample': '0.20', 'reg_alpha': '0.400', 'reg_lambda': '0.330', 'learning_rate': '0.199', 'num_leaves': '220.000', 'colsample_bytree': '0.457', 'min_child_samples': '120.000', 'feature_fraction': '0.640', 'bagging_fraction': '0.491'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:20:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.4836
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:21:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.5641
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:21:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.4733
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:21:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.5276
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:21:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.4949
# Total Time Run: 1.19
# Mean ROC_AUC: 1.0776433185418077
#
# ############## New Run ################
# params = {'max_depth': 21, 'gamma': '0.455', 'subsample': '0.20', 'reg_alpha': '0.394', 'reg_lambda': '0.334', 'learning_rate': '0.191', 'num_leaves': '220.000', 'colsample_bytree': '0.463', 'min_child_samples': '180.000', 'feature_fraction': '0.645', 'bagging_fraction': '0.500'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:22:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.5181
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:22:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.4417
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:22:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.4146
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:22:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.5006
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:23:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.4608
# Total Time Run: 1.38
# Mean ROC_AUC: 1.0479580702498583
#
# ############## New Run ################
# params = {'max_depth': 23, 'gamma': '0.690', 'subsample': '0.40', 'reg_alpha': '0.349', 'reg_lambda': '0.330', 'learning_rate': '0.198', 'num_leaves': '220.000', 'colsample_bytree': '0.522', 'min_child_samples': '210.000', 'feature_fraction': '0.543', 'bagging_fraction': '0.580'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:23:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.2172
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:24:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.237
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:24:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.1619
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:25:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.2334
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:25:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.2414
# Total Time Run: 2.93
# Mean ROC_AUC: 0.870124821337855
#
# ############## New Run ################
# params = {'max_depth': 20, 'gamma': '0.630', 'subsample': '0.20', 'reg_alpha': '0.394', 'reg_lambda': '0.383', 'learning_rate': '0.139', 'num_leaves': '180.000', 'colsample_bytree': '0.556', 'min_child_samples': '120.000', 'feature_fraction': '0.642', 'bagging_fraction': '0.518'}
# ==================================================
# Training Start, fold : 1
# ==================================================
# [19:26:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1 CV - score: 1.3327
# ==================================================
# Training Start, fold : 2
# ==================================================
# [19:26:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 2 CV - score: 1.3092
# ==================================================
# Training Start, fold : 3
# ==================================================
# [19:26:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 3 CV - score: 1.282
# ==================================================
# Training Start, fold : 4
# ==================================================
# [19:27:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4 CV - score: 1.2977
# ==================================================
# Training Start, fold : 5
# ==================================================
# [19:27:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5 CV - score: 1.2932
# Total Time Run: 1.24
# Mean ROC_AUC: 0.9306766228023015
# 100%|██████████| 27/27 [34:51<00:00, 77.47s/it, best loss: -1.0947213150984239]

# %% [markdown]
# # Best parameters

# %%
print("BEST PARAMS: ", best_params)

best_params['max_depth'] = int(best_params['max_depth'])
# Out:
# BEST PARAMS:  {'bagging_fraction': 0.4924424099711338, 'colsample_bytree': 0.47917146335117106, 'feature_fraction': 0.5410689507241268, 'gamma': 0.6958871934464437, 'learning_rate': 0.19974558926399488, 'max_depth': 20.0, 'min_child_samples': 100, 'num_leaves': 220, 'reg_alpha': 0.37242188170834345, 'reg_lambda': 0.32701197628586554, 'subsample': 0.2}

# %% [markdown]
# # Trainning and Predicting with best Parameters

# %% [markdown]
# ## Predicting X test

# %%
clf = xgb.XGBRegressor(
    n_estimators=300,
    **best_params,
    tree_method='gpu_hist'
)

clf.fit(X_train, y_train)

#y_preds = clf.predict_proba(X_test)[:,1]
# Out:
# [19:27:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# /opt/conda/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning:
#
# Series.base is deprecated and will be removed in a future version
# XGBRegressor(bagging_fraction=0.4924424099711338, base_score=0.5,
#              booster='gbtree', colsample_bylevel=1, colsample_bynode=1,
#              colsample_bytree=0.47917146335117106,
#              feature_fraction=0.5410689507241268, gamma=0.6958871934464437,
#              importance_type='gain', learning_rate=0.19974558926399488,
#              max_delta_step=0, max_depth=20, min_child_samples=100,
#              min_child_weight=1, missing=None, n_estimators=300, n_jobs=1,
#              nthread=None, num_leaves=220, objective='reg:linear',
#              random_state=0, reg_alpha=0.37242188170834345,
#              reg_lambda=0.32701197628586554, scale_pos_weight=1, seed=None,
#              silent=None, subsample=0.2, tree_method='gpu_hist', verbosity=1)

# %% [markdown]
# # Top 20 Feature importance

# %%
feature_important = clf.get_booster().get_score(importance_type="weight")
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)

# Top 10 features
data.head(20)
# Out:
#                      score
# time_gap             12407
# game_time            10782
# total_time            7274
# Assessment_time_per   6698
# Clip_time_per         6383
# time_percentage       6026
# Activity_time_per     5519
# Game_time_per         5356
# code_4xx_time         4561
# session_count         3407
# between_3xxx          3178
# hour_session          2828
# day_session           2714
# 2020                  2069
# 4025                  1934
# 3020                  1879
# 4070                  1845
# 3010                  1744
# Clip                  1654
# 3021                  1543

# %%
data.to_csv('features_xgb.csv')

# %% [markdown]
# ## Seting y_pred to csv

# %%
#sample_submission['isFraud'] = y_preds
#sample_submission.to_csv('XGB_hypopt_model.csv')

# %% [markdown]
# ## I'm working in this kernel yet.
# # <font color="red">Please if this kernel were useful for you, please <b>UPVOTE</b> =)</font>
